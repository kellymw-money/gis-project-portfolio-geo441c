# %% [markdown]
# <a href="https://colab.research.google.com/github/kellymw-money/gis-project-portfolio-geo441c/blob/main/Copy_of_week_11_assignment_template.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Replicating John Snow's discovery on the cause of cholera spread in Soho, London**

# %% [markdown]
# 🚀 Created by [Max Kelly]
#
# [4/24/2026]

# %% [markdown]
# ## **Get ready to start**
#
# - Click **`File/Save a copy in Drive`** to save a copy of this notebook to my own Google Drive

# %% [markdown]
# ## **Overview**
#
# - This notebook shows three maps created based on geospatial data to replicate Dr. John Snow's discovery on the root cause of the spread of cholera in London during 1850s, a prime example of geospatial analysis and the onset of the epidemology.
#
#     <div>
#     <img src="https://adventuresinmapping.com/wp-content/uploads/2023/12/johnsnowcholeramap.png" width= 700px />
#     </div>

# %% [markdown]
# ## **Map 1: Number of addresses with cholera deaths reported**

# %% [markdown]
# - Use the checklist below to make sure our map contains all necessary map content and is formatted correctly
#
#   - [ x] Contains a title with byline (i.e., by [your name])
#   - [x ] Use a larger and bold font type for the title
#   - [ x] Contains a layer of **pumps**
#   - [ x] Contains a layer of **100 meter buffer around pump**
#   - [ x] Contains a map scale
#   - [x ] Contains a legend
#   - [x ] Contains a north arrow
#   - [x ] Uses a balanced layout for all map elements
#     - [ x] Map stays in the center of layout
#     - [x ] Font size of title is appropriate (not too big or too small)
#     - [x ] Legend, map scale bar, and north arrow are placed appropriately to avoid an overlap with the map layers
#     - [ x] Legend, map scale bar, and north arrow has an appropriate size (big enough to read information, small enough to reserve most of space for map layers

# %% [markdown]
# ```markdown
# [https://drive.google.com/file/d/1FpqDixvTvxfclZ1_yQywu1RAUwtB0ngt/view?usp=sharing]
# ```
#
# - After finishing the two steps below, a link can be created to correctly rendered in Google Colab
#   - Deleted **`/view?usp=sharing`** at the end of the link
#   - Replaced **`/file/d/`** with **`/uc?export=view&id=`**
#
# ```markdown
# [https://drive.google.com/uc?export=view&id=1FpqDixvTvxfclZ1_yQywu1RAUwtB0ngt]
# ```
#
# - The map can be inserted in Google Colab following the syntax [from here](https://www.markdownguide.org/cheat-sheet/)
#
# ```markdown
# Insert the map here using syntax:
# ![address with cholera deaths](https://drive.google.com/uc?export=view&id=1FpqDixvTvxfclZ1_yQywu1RAUwtB0ngt)
# ```
#
# ![address with cholera deaths](https://drive.google.com/uc?export=view&id=1FpqDixvTvxfclZ1_yQywu1RAUwtB0ngt)

# %% [markdown]
# ## **Map 2: Number of deaths related to cholera in Soho, London**

# %% [markdown]
# - Use the checklist below to make sure our map contains all necessary map content and is formatted correctly
#
#   - [x] Contains a title with byline (i.e., by [your name])
#   - [ x] Use a larger and bold font type for the title
#   - [ x] Contains a layer of **pumps**
#   - [ x] Contains a layer of **100 meter buffer around pump**
#   - [ x] The buffer layer is mapped by the **count of reported deaths related to cholera**
#   - [ x] Contains a map scale
#   - [ x] Contains a legend
#   - [ x] Contains a north arrow
#   - [ x] Uses a balanced layout for all map elements
#     - [x] Map stays in the center of layout
#     - [x ] Font size of title is appropriate (not too big or too small)
#     - [ x] Legend, map scale bar, and north arrow are placed appropriately to avoid an overlap with the map layers
#     - [x ] Legend, map scale bar, and north arrow has an appropriate size (big enough to read information, small enough to reserve most of space for map layers

# %% [markdown]
# ```markdown
# [https://drive.google.com/file/d/1_id9h6CgM42I9XwtTITulPV5Cpk3a1IG/view?usp=sharing]
# ```
#
# - After finishing the two steps below, a link can be created to correctly rendered in Google Colab
#   - Deleted **`/view?usp=sharing`** at the end of the link
#   - Replaced **`/file/d/`** with **`/uc?export=view&id=`**
#
# ```markdown
# [https://drive.google.com/uc?export=view&id=1_id9h6CgM42I9XwtTITulPV5Cpk3a1IG]
# ```
#
# - The map can be inserted in Google Colab following the syntax [from here](https://www.markdownguide.org/cheat-sheet/)
#
# ```markdown
# Insert the map here using syntax:
# ![cholera deaths](https://drive.google.com/uc?export=view&id=1_id9h6CgM42I9XwtTITulPV5Cpk3a1IG)
# ```
#
# ![cholera deaths](https://drive.google.com/uc?export=view&id=1_id9h6CgM42I9XwtTITulPV5Cpk3a1IG)

# %% [markdown]
# ## **Map 3: Hot spots of cholera deaths in Soho, London (1850s)**

# %% [markdown]
# - Use the checklist below to make sure our map contains all necessary map content and is formatted correctly
#
#   - [x] Contains a title with byline (i.e., by [your name])
#   - [x ] Use a larger and bold font type for the title
#   - [x ] Contains a layer of **pumps**
#   - [ x] Contains a layer of **hot spots of cholera deaths**
#   - [ x] Contains a map scale
#   - [x ] Contains a legend
#   - [x ] Contains a north arrow
#   - [x ] Uses a balanced layout for all map elements
#     - [x ] Map stays in the center of layout
#     - [x ] Font size of title is appropriate (not too big or too small)
#     - [ x] Legend, map scale bar, and north arrow are placed appropriately to avoid an overlap with the map layers
#     - [ x] Legend, map scale bar, and north arrow has an appropriate size (big enough to read information, small enough to reserve most of space for map layers

# %% [markdown]
# ```markdown
# [https://drive.google.com/file/d/1e3OC9QJPG5Dn74Lq1GamfPjusf70V2rv/view?usp=sharing]
# ```
#
# - After finishing the two steps below, a link can be created to correctly rendered in Google Colab
#   - Deleted **`/view?usp=sharing`** at the end of the link
#   - Replaced **`/file/d/`** with **`/uc?export=view&id=`**
#
# ```markdown
# [https://drive.google.com/uc?export=view&id=1e3OC9QJPG5Dn74Lq1GamfPjusf70V2rv]
# ```
#
# - The map can be inserted in Google Colab following the syntax [from here](https://www.markdownguide.org/cheat-sheet/)
#
# ```markdown
# Insert the map here using syntax:
# ![cholera hot spot](https://drive.google.com/uc?export=view&id=1e3OC9QJPG5Dn74Lq1GamfPjusf70V2rv)
# ```
#
# ![cholera hot spot](https://drive.google.com/uc?export=view&id=1e3OC9QJPG5Dn74Lq1GamfPjusf70V2rv)

# %% [markdown]
# ## **Save and share this notebook**
#
# - **Save the final version of this notebook to your GitHub repository of GEO 441/541C**
#   - You can place this notebook under a new folder of `spatial_analysis`
#   - Update your README document to link the copy of this notebook in the GitHub repository
# - Submit a link to your GitHub for Week 11 assignment

# %% [markdown]
# ## **Reference**
#
# - [Markdown cheat sheet](https://www.markdownguide.org/cheat-sheet/)
# - [Insert other references]
