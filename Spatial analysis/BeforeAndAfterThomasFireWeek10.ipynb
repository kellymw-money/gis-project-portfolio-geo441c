# %% [markdown]
# <a href="https://colab.research.google.com/github/kellymw-money/gis-project-portfolio-geo441c/blob/main/Copy_of_week_10_raster_analysis_Thomas_fire.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Inspect Landsat-8 image before and after Thomas Fire (Dec. 2017 - Jan. 2018, California)**

# %% [markdown]
# 🚀 Created by [Your Name]

# %% [markdown]
# ## **Get ready to start**
#
# - Click **`File/Save a copy in Drive`** to save a copy of this notebook to your own Google Drive

# %% [markdown]
# ## **Thomas Fire in December, 2017**
#
# - The Thomas Fire was a massive wildfire that affected Ventura and Santa Barbara Counties, and one of multiple wildfires that ignited in southern California in December 2017.
# - It burned approximately 281,893 acres (440 sq mi; 114,078 ha) before being fully contained on January 12, 2018, making it the largest wildfire in modern California history at the time.
# - Read more about Thomas fire from [this storymap](https://storymaps.arcgis.com/stories/d943c491f711403dab28961dbcdd6ce8)
#
# ---

# %% [markdown]
# ## **Image for this practice**
#
# - [Landsat-8 surface reflectance products (level-2 products)](https://www.usgs.gov/landsat-missions/landsat-collection-2-level-2-science-products) obtained on
#   - 11/23/2017
#   - 1/28/2018
# ---

# %% [markdown]
# ## **Compare images before and after Thomas fire**
#
# - Use a band combination of 6-5-3
#   - Red channel: Band 6 (SWIR)
#   - Green channel: Band 5 (NIR)
#   - Blue channel: Band 3 (Green)
#
# ---

# %% [markdown]
# ## **Calculate NDVI for both images**
#
# - Comparing NDVI is a more straightforward way to identify how much damage the fire caused on the natural landscape
# - NDVI is designed to highlight the "red edge" effects of drastic change in the reflectance between the red and near infrared bands
#
#   <div>
#   <img src="https://ltb.itc.utwente.nl/uploads/studyarea/491/Pics_2015_jpg/Fig2_13.jpg" width= 500px />
#   </div>
#
#
#
# - NDVI can be calculated using the following equation with **Raster Calculator**
#
#   $
#   NDVI = \frac{(NIR - Red)}{(NIR + Red)}
#   $
#
# - In Landsat-8, we will use the following bands to calculate NDVI
#
#   $
#   NDVI = \frac{(Band\,5 - Band\,4)}{(Band\,5 + Band\,4)}
#   $

# %% [markdown]
# ## **Compute the change in NDVI**
#
# - We can overlay the two NDVI images and calculate the difference between them using **Raster Calculator**

# %% [markdown]
# ## **Use the ArcGIS Pro `.aprx` file provided to create a map**
#
# - Download the `aprx` provided in Week 10 module and reset the **sources of data** to restore the images used for mapping
#
# - Steps to produce a link can be correctly rendered in Google Colab Notebook using Markdown
#   - Upload the map picture to a Google Drive folder and share it with public
#   - Copy the link to this picture file and paste it in the markdown cell
#   - Edit the link
#     - Deleted `/view?usp=sharing` at the end of the link
#     - Replaced `/file/d/` with `/uc?export=view&id=`
# - Use the following Markdown syntax to insert a map to my Google Colab Notebook
#   - `![image](https://drive.google.comuc?export=view&id=1rHgq6zqJ9Ohcff86IXfqHdTDWPaAQSGZ)`
#
# ![Change in NDVI](https://drive.google.com/uc?export=view&id=129mFaj_bNEP3TX6X6586J_RuA3Tc9Qyb)
#
# - You should be able to get an image like the one below
#
#   <div>
#   <img src="https://drive.google.com/uc?export=view&id=1VTzBFukGHc3DuRme5meukgj92G5QahOp" width= 800px />
#   </div>

# %% [markdown]
# ## **Map the average of slope inside all blocks in Santa Barbara County and Ventura County, CA**
#
# - We can use zonal statistics to calculate several basic statistic values to represent an overal situation of slope inside all blocks in Santa Barbara County and Ventura County, where the damange caused by Thomas fire was the largest
#   - Blocks with the steepest slope also experienced a great risk of [mudslide in January, 2018](https://en.wikipedia.org/wiki/2018_Southern_California_mudflows), following a series of storms
#
# - Download `GEO441_Spring26_Week10_Terrain_Analysis.aprx` and follow [slides of 4/3/26](https://docs.google.com/presentation/d/13tQa31xUuW6EqKGNpfiNF2ZEOjZ3QVwLfqHviB-Qj4A/edit?usp=sharing) to create your zonal stats results and a map
# - Steps to produce a link can be correctly rendered in Google Colab Notebook using Markdown
#   - Upload the map picture to a Google Drive folder and share it with public
#   - Copy the link to this picture file and paste it in the markdown cell
#   - Edit the link
#     - Deleted `/view?usp=sharing` at the end of the link
#     - Replaced `/file/d/` with `/uc?export=view&id=`
# - Use the following Markdown syntax to insert a map to my Google Colab Notebook
#   - `![image](https://drive.google.com/uc?export=view&id=1F71EJME51EgKBQHZ_UlrsIO26wi3VT7R)`
# - Insert your map of average slope by blocks below
# ---
# ![Slope](https://drive.google.com/uc?export=view&id=1Owr-LS6ZNKuU8GxYTxbx_yCMd348wIRa)

# %% [markdown]
# ## **Save notebook to GitHub**
#
# - Save this notebook to GitHub repository you made before
# - [Optional]Create a new folder by copying the following line to your repository path
#   - `raster-data-analysis/ndvi-change-thomas-fire.ipynb`
# - Update your **readme** page with a link to the copied notebook in GitHub
