# %% [markdown]
# <a href="https://colab.research.google.com/github/kellymw-money/gis-project-portfolio-geo441c/blob/main/week_01_assignment_Kellymw.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **GEO 441B/541B Week 1 Assignment: Introduction to ArcGIS Pro GUI**

# %% [markdown]
# 🚀 Created by Max Kelly
# 2/10/2026

# %% [markdown]
# ### **Get ready to start**
#
# - Click **`File/Save a copy in Drive`** to save a copy of this notebook to my own Google Drive

# %% [markdown]
# ### **Create my first map using ArcGIS Pro**
#
#    - Follow mapping instructions from [this Canvas file](https://miamioh.instructure.com/courses/218994/files/32640807?wrap=1)
#    - Mapping instructions are adapted from *Lab 1: Introduction to ArcGIS Pro* in [GIS Fundamentals Resources page](https://www.gisfundamentals.org/resources)

# %% [markdown]
# ###**Insert my first map into a Markdown cell**
#
# **Step 1. Copy the sharing link of your PNG file**
#
# Upload your map as a PNG file to your Google Drive folder.
#
# Right-click the file → Get link
#
# Make sure the permission is set to “Anyone with the link → Viewer”
#
# Copy the link.
#
# Paste your original Google Drive link below (for reference only), then delete this line:
#
# ```markdown
# https://drive.google.com/file/d/1MOWDP-m2f0JculnCUHPVj7PeIRYZrqRM/view?usp=sharing
# ```

# %% [markdown]
# **Step 2. Modify the Google Drive link so it can render in Colab**
#
# To make the image render correctly in Markdown, update the link as follows:
#
# Delete `/view?usp=sharing` at the end of the link
#
# Replace `/file/d/` with `/uc?export=view&id=`
#
# After making these two edits, paste your revised link below and remove this line:
#
# ```markdown
# https://drive.google.com/uc?export=view&id=1MOWDP-m2f0JculnCUHPVj7PeIRYZrqRM
# ```

# %% [markdown]
# **Step 3. Insert the image using Markdown image syntax**
#
# Use the Markdown image syntax shown below.
# Replace **revised link** with your actual revised Google Drive link.
#
# ```markdown
# ![potential campground](https://drive.google.com/uc?export=view&id=1MOWDP-m2f0JculnCUHPVj7PeIRYZrqRM)
# ```
#
# 🔹 The text inside the square brackets (potential campground) is the image caption (alt text).
# You may change it to a more descriptive label for your map.

# %% [markdown]
# ###**Map Result**
#
#    ![potential campground](https://drive.google.com/uc?export=view&id=1MOWDP-m2f0JculnCUHPVj7PeIRYZrqRM)<!-- Example Image Placeholder -->

# %% [markdown]
# ### **Reflection on my first experience with ArcGIS Pro**
#
# - Overall, I spent [2 hours] to finish creating my first map
# - Here is a table showing things that I feel excited and challenging in my first experience working in ArcGIS Pro
#
# | Things I'm excited about      | Things challenging for me  |
# | ----------------------------- | -------------------------- |
# | [Getting more skilled with ArcGIS]     | File management |
# | [Practicing file management]     | [Computing jargon]    |
# | [Learning about different jobs in this field]      | [organization]   |
#
# - Here is how I rate my first experience working in ArcGIS Pro
#   - Data important and management
#     - [This was the hardest part for me. I struggle with file management so keeping everything organized was a headache for me. I am happy to have the practice though because I am getting more used to it.]
#   - Map creation and annotation
#     - [I did not really struggle with this at all. I found ArcGIS similar to excel in format which is something I have a lot of practice with. This part of the assignment was pretty easy and satisfying for me. I know we are doing easy stuff right now but this might be a new skill.]
#   - Navigate the software using its GUI
#     - [Similar to my last answer I found this decently easy. The thing I stuggled with the most was making sure everything was saving in the right place and uploading data.]

# %% [markdown]
# ### **Save and share this notebook**
#
# - I made this notebook viewable by anyone with the link
#
# ![Share Notebook](https://drive.google.com/uc?export=view&id=1K4a3saeAXrzKcB4fkivkjUmLLWJ1R7oS)
#
# - Then I copied [this link](https://colab.research.google.com/drive/1HsxBr7gp56dc5qH_y4Nbj8A-eBbkaye2?usp=sharing) as my submission to Assignment Week 1

# %% [markdown]
# ### **Reference**
#
# - [Markdown cheat sheet](https://www.markdownguide.org/cheat-sheet/)
